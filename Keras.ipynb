# %%
import keras as kr
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('house_price_full.csv')
df.head(1)
# Out:
#    bedrooms  sqft_living   price
# 0         3         1340  313000

# %%
X = df.copy()
Y  = X.pop('price')
scaler = StandardScaler()
X = scaler.fit_transform(X)
Y = np.log(Y)

# %%
X[0]
# Out:
# array([-0.43319764, -0.75325754])

# %%
Y[0:2]
# Out:
# 0    12.653958
# 1    14.684290
# Name: price, dtype: float64

# %%
model = kr.Sequential([
    kr.layers.Dense(2,input_shape = (X.shape[-1],),activation = "sigmoid")
    ,kr.layers.Dense(1,activation='linear') ]
)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 2)                 6
#
#  dense_5 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
X.shape[-1]
# Out:
# 2

# %%
model.compile(optimizer=kr.optimizers.SGD(), loss = 'mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 2)                 6
#
#  dense_5 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X,Y.values,epochs = 10,batch_size=32)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 1s 2ms/step - loss: 111.9554
# Epoch 2/10
# 16/16 [==============================] - 0s 2ms/step - loss: 32.2099
# Epoch 3/10
# 16/16 [==============================] - 0s 2ms/step - loss: 7.3939
# Epoch 4/10
# 16/16 [==============================] - 0s 2ms/step - loss: 1.7764
# Epoch 5/10
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6220
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3686
# Epoch 7/10
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2904
# Epoch 8/10
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2517
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2256
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2060

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 2)                 6
#
#  dense_5 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.predict(X)[:,0]
# Out:
# 16/16 [==============================] - 0s 2ms/step
# array([12.812578 , 13.302144 , 13.193182 , 13.232371 , 12.771124 ,
#        12.905638 , 13.210846 , 13.23373  , 13.446916 , 12.468794 ,
#        13.06189  , 13.338694 , 13.400921 , 12.623646 , 12.914371 ,
#        12.708805 , 12.9718   , 13.425964 , 12.834141 , 12.693558 ,
#        13.357544 , 12.415187 , 13.086689 , 13.244116 , 12.528959 ,
#        13.28096  , 13.414959 , 12.940925 , 12.861662 , 13.519972 ,
#        12.499024 , 13.309624 , 12.688205 , 13.289837 , 13.629216 ,
#        13.742544 , 12.847004 , 13.146877 , 13.210129 , 13.428792 ,
#        12.978406 , 12.438271 , 12.8838825, 13.098934 , 13.126786 ,
#        12.6782055, 13.215727 , 13.193182 , 12.761339 , 13.510149 ,
#        13.23373  , 13.637533 , 13.563929 , 13.1171055, 12.477028 ,
#        12.757501 , 12.934647 , 13.306793 , 12.798071 , 13.362505 ,
#        13.510149 , 13.552191 , 13.244116 , 13.494911 , 13.338694 ,
#        12.919985 , 13.023909 , 12.559723 , 13.764857 , 13.337652 ,
#        13.136534 , 13.6162815, 12.990408 , 13.176008 , 12.805338 ,
#        13.163506 , 12.922031 , 13.244116 , 12.890133 , 13.473427 ,
#        12.804832 , 13.649502 , 13.7241125, 13.1171055, 13.026656 ,
#        13.575922 , 13.082613 , 12.911163 , 13.245159 , 13.120565 ,
